# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_csv('infy_stock.csv', index_col='Date', parse_dates=True)

# %%
df
# Out:
#            Symbol Series  Prev Close     Open     High     Low     Last  \
# Date
# 2015-01-01   INFY     EQ     1972.55  1968.95  1982.00  1956.9  1971.00
# 2015-01-02   INFY     EQ     1974.40  1972.00  2019.05  1972.0  2017.95
# 2015-01-05   INFY     EQ     2013.20  2009.90  2030.00  1977.5  1996.00
# 2015-01-06   INFY     EQ     1995.90  1980.00  1985.00  1934.1  1965.10
# 2015-01-07   INFY     EQ     1954.20  1965.00  1974.75  1950.0  1966.05
# ...           ...    ...         ...      ...      ...     ...      ...
# 2015-12-24   INFY     EQ     1100.85  1102.05  1104.45  1090.1  1095.80
# 2015-12-28   INFY     EQ     1096.35  1090.00  1110.00  1090.0  1103.80
# 2015-12-29   INFY     EQ     1104.75  1101.25  1110.00  1097.3  1103.00
# 2015-12-30   INFY     EQ     1104.70  1101.10  1106.60  1083.0  1088.00
# 2015-12-31   INFY     EQ     1086.30  1090.15  1109.95  1087.0  1107.00
#
#               Close     VWAP   Volume      Turnover  Trades  \
# Date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 248 entries, 2015-01-01 to 2015-12-31
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              248 non-null    object
#  1   Series              248 non-null    object
#  2   Prev Close          248 non-null    float64
#  3   Open                248 non-null    float64
#  4   High                248 non-null    float64
#  5   Low                 248 non-null    float64
#  6   Last                248 non-null    float64
#  7   Close               248 non-null    float64
#  8   VWAP                248 non-null    float64
#  9   Volume              248 non-null    int64
#  10  Turnover            248 non-null    float64
#  11  Trades              248 non-null    int64
#  12  Deliverable Volume  248 non-null    int64
#  13  %Deliverble         248 non-null    float64
# dtypes: float64(9), int64(3), object(2)
# ...

# %%
df.isna().sum()
# Out:
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(12, 6))
plt.plot(df['Close'])
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('date wise close')
plt.grid()
plt.show()

# %%
start_date = '2015'
end_date = '2016'
plot = df['Close'].plot(
            title=f'Closing Prices from {start_date} - {end_date}',
            ylabel= 'Closing Price')
# plt.savefig('images/fig_9.1.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 start_date = '2015'
#       2 end_date = '2016'
# ----> 3 plot = df['Close'].plot(
#       4             title=f'Closing Prices from {start_date} - {end_date}',
#       5             ylabel= 'Closing Price')
#       6 # plt.savefig('images/fig_9.1.png', bbox_inches='tight')
#
# NameError: name 'df' is not defined
